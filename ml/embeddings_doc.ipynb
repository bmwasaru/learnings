# %%
from transformers import BertTokenizer, BertModel

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

text = "where were you yesterday night?"
tokenized_text = tokenizer.tokenize(text)
print(tokenized_text)
# Out:
# ['where', 'were', 'you', 'yesterday', 'night', '?']

# %%
# !pip install ollama pandas

import csv
import pandas as pd

def read_books_dataset_csv(path):
    df = pd.read_csv(path, usecols=['Description'])
    return df
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: pip install --upgrade pip

# %%
import ollama


books_df = pd.DataFrame()
books_df["description"] = read_books_dataset_csv('../data/BooksDatasetClean.csv')

books = ollama.embed(
    model='hf.co/Qwen/Qwen3-Embedding-8B-GGUF:Q8_0',
    input=[
        x for x in books_df
    ],
)

print(books["embeddings"])
# Out:
# [[0.019218488, 0.01531584, 0.0005725882, 0.0014986661, 0.008039993, -0.019838367, -0.012936943, 0.015129206, -0.007309249, 0.008903772, -0.04638293, 0.008020424, 0.05227368, -0.022302857, 0.009974123, -0.0022745978, 0.0035008162, -0.0008676205, 0.028464561, 0.053048898, 0.0142639, 0.0468038, 0.00040955574, -0.01270993, -0.006048205, 0.04120569, -0.006052044, -0.015923329, -0.0055145416, 0.012406045, -0.00066384, -0.016166093, 0.020641098, 0.03283029, -0.028171334, 0.028752752, -0.010056562, 0.0026302272, 0.0017061938, -0.018246735, -0.022657419, -0.0074149678, -0.008799247, 0.014039219, 0.014351891, -0.0009961629, -0.025725765, -0.007946412, 0.02514535, -0.0009940476, 0.004288353, -0.023342064, -0.017565692, -0.012371183, 0.015766703, 0.00890893, -0.019912671, -0.005492947, -0.029467545, -0.0075856126, -0.06110227, -0.013205185, 0.020699961, -0.01706267, -0.0045448886, 4.6476158e-05, 0.0034512249, -0.02686758, 0.023623135, -0.0035939266, 0.0036143071, 0.014572935, 0.022960864, -0.010
# ...
